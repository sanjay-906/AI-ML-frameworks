# %% [markdown]
# # Unit 3: Deep Q-Learning with Atari Games 👾 using RL Baselines3 Zoo
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit4/thumbnail.jpg" alt="Unit 3 Thumbnail">
#
# In this notebook, **you'll train a Deep Q-Learning agent** playing Space Invaders using [RL Baselines3 Zoo](https://github.com/DLR-RM/rl-baselines3-zoo), a training framework based on [Stable-Baselines3](https://stable-baselines3.readthedocs.io/en/master/) that provides scripts for training, evaluating agents, tuning hyperparameters, plotting results and recording videos.
#
# We're using the [RL-Baselines-3 Zoo integration, a vanilla version of Deep Q-Learning](https://stable-baselines3.readthedocs.io/en/master/modules/dqn.html) with no extensions such as Double-DQN, Dueling-DQN, and Prioritized Experience Replay.
#
# ⬇️ Here is an example of what **you will achieve** ⬇️

# %%
# %%html
# <video controls autoplay><source src="https://huggingface.co/ThomasSimonini/ppo-SpaceInvadersNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>
# Out:
# <video controls autoplay><source src="https://huggingface.co/ThomasSimonini/ppo-SpaceInvadersNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>

# %% [markdown]
# ### 🎮 Environments:
#
# - [SpacesInvadersNoFrameskip-v4](https://gymnasium.farama.org/environments/atari/space_invaders/)
#
# You can see the difference between Space Invaders versions here 👉 https://gymnasium.farama.org/environments/atari/space_invaders/#variants
#
# ### 📚 RL-Library:
#
# - [RL-Baselines3-Zoo](https://github.com/DLR-RM/rl-baselines3-zoo)

# %% [markdown]
# ## Objectives of this notebook 🏆
# At the end of the notebook, you will:
# - Be able to understand deeper **how RL Baselines3 Zoo works**.
# - Be able to **push your trained agent and the code to the Hub** with a nice video replay and an evaluation score 🔥.

# %% [markdown]
# ## This notebook is from Deep Reinforcement Learning Course
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/deep-rl-course-illustration.jpg" alt="Deep RL Course illustration"/>

# %% [markdown]
# In this free course, you will:
#
# - 📖 Study Deep Reinforcement Learning in **theory and practice**.
# - 🧑‍💻 Learn to **use famous Deep RL libraries** such as Stable Baselines3, RL Baselines3 Zoo, CleanRL and Sample Factory 2.0.
# - 🤖 Train **agents in unique environments**
#
# And more check 📚 the syllabus 👉 https://simoninithomas.github.io/deep-rl-course
#
# Don’t forget to **<a href="http://eepurl.com/ic5ZUD">sign up to the course</a>** (we are collecting your email to be able to **send you the links when each Unit is published and give you information about the challenges and updates).**
#
#
# The best way to keep in touch is to join our discord server to exchange with the community and with us 👉🏻 https://discord.gg/ydHrjt3WP5

# %% [markdown]
# ## Prerequisites 🏗️
# Before diving into the notebook, you need to:
#
# 🔲 📚 **[Study Deep Q-Learning by reading Unit 3](https://huggingface.co/deep-rl-course/unit3/introduction)**  🤗

# %% [markdown]
# We're constantly trying to improve our tutorials, so **if you find some issues in this notebook**, please [open an issue on the Github Repo](https://github.com/huggingface/deep-rl-class/issues).

# %% [markdown]
# # Let's train a Deep Q-Learning agent playing Atari' Space Invaders 👾 and upload it to the Hub.
#
# We strongly recommend students **to use Google Colab for the hands-on exercises instead of running them on their personal computers**.
#
# By using Google Colab, **you can focus on learning and experimenting without worrying about the technical aspects of setting up your environments**.
#
# To validate this hands-on for the certification process, you need to push your trained model to the Hub and **get a result of >= 200**.
#
# To find your result, go to the leaderboard and find your model, **the result = mean_reward - std of reward**
#
# For more information about the certification process, check this section 👉 https://huggingface.co/deep-rl-course/en/unit0/introduction#certification-process

# %% [markdown]
# ## An advice 💡
# It's better to run this colab in a copy on your Google Drive, so that **if it timeouts** you still have the saved notebook on your Google Drive and do not need to fill everything from scratch.
#
# To do that you can either do `Ctrl + S` or `File > Save a copy in Google Drive.`
#
# Also, we're going to **train it for 90 minutes with 1M timesteps**. By typing `!nvidia-smi` will tell you what GPU you're using.
#
# And if you want to train more such 10 million steps, this will take about 9 hours, potentially resulting in Colab timing out. In that case, I recommend running this on your local computer (or somewhere else). Just click on: `File>Download`.

# %% [markdown]
# ## Set the GPU 💪
# - To **accelerate the agent's training, we'll use a GPU**. To do that, go to `Runtime > Change Runtime type`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step1.jpg" alt="GPU Step 1">

# %% [markdown]
# - `Hardware Accelerator > GPU`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step2.jpg" alt="GPU Step 2">

# %% [markdown]
# # Install RL-Baselines3 Zoo and its dependencies 📚
#
# If you see `ERROR: pip's dependency resolver does not currently take into account all the packages that are installed.` **this is normal and it's not a critical error** there's a conflict of version. But the packages we need are installed.

# %%
# !pip install git+https://github.com/DLR-RM/rl-baselines3-zoo
# Out:
# Collecting git+https://github.com/DLR-RM/rl-baselines3-zoo
#   Cloning https://github.com/DLR-RM/rl-baselines3-zoo to /tmp/pip-req-build-k1yuz9_k
#   Running command git clone --filter=blob:none --quiet https://github.com/DLR-RM/rl-baselines3-zoo /tmp/pip-req-build-k1yuz9_k
#   Resolved https://github.com/DLR-RM/rl-baselines3-zoo to commit 506bb7aa40e9d90e997580a369f2e9bf64abe594
#   Running command git submodule update --init --recursive -q
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting sb3_contrib<3.0,>=2.5.0a0 (from rl_zoo3==2.5.0a1)
#   Downloading sb3_contrib-2.5.0a0-py3-none-any.whl.metadata (3.8 kB)
# Collecting gymnasium<1.1.0,>=0.29.1 (from rl_zoo3==2.5.0a1)
#   Downloading gymnasium-1.0.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting huggingface_sb3<4.0,>=3.0 (from rl_zoo3==2.5.0a1)
#   Downloading huggingface_sb3-3.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from rl_zoo3==2.5.0a1) (4.67.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from rl_zoo3==2.5.0a1) (13.9.4)
# Collecting optuna>=3.0 (from rl_zoo3==2.5.0a1)
#   Downloading optuna-4.2.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from rl_zoo3==2.5.0a1) (6.0.2)
# Collecting pytablewriter~=1.2 (from rl_zoo3==2.5.0a1)
#   Downloading pytablewriter-1.2.1-py3-none-any.whl.metadata (38 kB)
# Collecting shimmy~=2.0 (from rl_zoo3==2.5.0a1)
#   Downloading Shimmy-2.0.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.1.0,>=0.29.1->rl_zoo3==2.5.0a1) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.1.0,>=0.29.1->rl_zoo3==2.5.0a1) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.1.0,>=0.29.1->rl_zoo3==2.5.0a1) (4.12.2)
# Collecting farama-notifications>=0.0.1 (from gymnasium<1.1.0,>=0.29.1->rl_zoo3==2.5.0a1)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl.metadata (558 bytes)
# Requirement already satisfied: huggingface-hub~=0.8 in /usr/local/lib/python3.11/dist-packages (from huggingface_sb3<4.0,>=3.0->rl_zoo3==2.5.0a1) (0.27.1)
# Requirement already satisfied: wasabi in /usr/local/lib/python3.11/dist-packages (from huggingface_sb3<4.0,>=3.0->rl_zoo3==2.5.0a1) (1.1.3)
# Collecting alembic>=1.5.0 (from optuna>=3.0->rl_zoo3==2.5.0a1)
#   Downloading alembic-1.14.1-py3-none-any.whl.metadata (7.4 kB)
# Collecting colorlog (from optuna>=3.0->rl_zoo3==2.5.0a1)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna>=3.0->rl_zoo3==2.5.0a1) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna>=3.0->rl_zoo3==2.5.0a1) (2.0.37)
# Requirement already satisfied: setuptools>=38.3.0 in /usr/local/lib/python3.11/dist-packages (from pytablewriter~=1.2->rl_zoo3==2.5.0a1) (75.1.0)
# Collecting DataProperty<2,>=1.1.0 (from pytablewriter~=1.2->rl_zoo3==2.5.0a1)
#   Downloading DataProperty-1.1.0-py3-none-any.whl.metadata (11 kB)
# Collecting mbstrdecoder<2,>=1.0.0 (from pytablewriter~=1.2->rl_zoo3==2.5.0a1)
#   Downloading mbstrdecoder-1.1.4-py3-none-any.whl.metadata (4.3 kB)
# Collecting pathvalidate<4,>=2.3.0 (from pytablewriter~=1.2->rl_zoo3==2.5.0a1)
#   Downloading pathvalidate-3.2.3-py3-none-any.whl.metadata (12 kB)
# Collecting tabledata<2,>=1.3.1 (from pytablewriter~=1.2->rl_zoo3==2.5.0a1)
#   Downloading tabledata-1.3.4-py3-none-any.whl.metadata (3.7 kB)
# Collecting tcolorpy<1,>=0.0.5 (from pytablewriter~=1.2->rl_zoo3==2.5.0a1)
#   Downloading tcolorpy-0.1.7-py3-none-any.whl.metadata (6.3 kB)
# Collecting typepy<2,>=1.3.2 (from typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3==2.5.0a1)
#   Downloading typepy-1.3.4-py3-none-any.whl.metadata (9.2 kB)
# Collecting stable-baselines3<3.0,>=2.4.0 (from sb3_contrib<3.0,>=2.5.0a0->rl_zoo3==2.5.0a1)
#   Downloading stable_baselines3-2.4.1-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->rl_zoo3==2.5.0a1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->rl_zoo3==2.5.0a1) (2.18.0)
# Collecting Mako (from alembic>=1.5.0->optuna>=3.0->rl_zoo3==2.5.0a1)
#   Downloading Mako-1.3.8-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.5.0a1) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.5.0a1) (2024.10.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.5.0a1) (2.32.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->rl_zoo3==2.5.0a1) (0.1.2)
# Requirement already satisfied: chardet<6,>=3.0.4 in /usr/local/lib/python3.11/dist-packages (from mbstrdecoder<2,>=1.0.0->pytablewriter~=1.2->rl_zoo3==2.5.0a1) (5.2.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna>=3.0->rl_zoo3==2.5.0a1) (3.1.1)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3<3.0,>=2.4.0->sb3_contrib<3.0,>=2.5.0a0->rl_zoo3==2.5.0a1) (2.5.1+cu121)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from stable-baselines3<3.0,>=2.4.0->sb3_contrib<3.0,>=2.5.0a0->rl_zoo3==2.5.0a1) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from stable-baselines3<3.0,>=2.4.0->sb3_contrib<3.0,>=2.5.0a0->rl_zoo3==2.5.0a1) (3.10.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.0 in /usr/local/lib/python3.11/dist-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3==2.5.0a1) (2.8.2)
# Requirement already satisfied: pytz>=2018.9 in /usr/local/lib/python3.11/dist-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3==2.5.0a1) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil<3.0.0,>=2.8.0->typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3==2.5.0a1) (1.17.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3<3.0,>=2.4.0->sb3_contrib<3.0,>=2.5.0a0->rl_zoo3==2.5.0a1) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3<3.0,>=2.4.0->sb3_contrib<3.0,>=2.5.0a0->rl_zoo3==2.5.0a1) (3.1.5)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3<3.0,>=2.4.0->sb3_contrib<3.0,>=2.5.0a0->rl_zoo3==2.5.0a1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3<3.0,>=2.4.0->sb3_contrib<3.0,>=2.5.0a0->rl_zoo3==2.5.0a1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3<3.0,>=2.4.0->sb3_contrib<3.0,>=2.5.0a0->rl_zoo3==2.5.0a1) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3<3.0,>=2.4.0->sb3_contrib<3.0,>=2.5.0a0->rl_zoo3==2.5.0a1) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3<3.0,>=2.4.0->sb3_contrib<3.0,>=2.5.0a0->rl_zoo3==2.5.0a1) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3<3.0,>=2.4.0->sb3_contrib<3.0,>=2.5.0a0->rl_zoo3==2.5.0a1) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3<3.0,>=2.4.0->sb3_contrib<3.0,>=2.5.0a0->rl_zoo3==2.5.0a1) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3<3.0,>=2.4.0->sb3_contrib<3.0,>=2.5.0a0->rl_zoo3==2.5.0a1) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3<3.0,>=2.4.0->sb3_contrib<3.0,>=2.5.0a0->rl_zoo3==2.5.0a1) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3<3.0,>=2.4.0->sb3_contrib<3.0,>=2.5.0a0->rl_zoo3==2.5.0a1) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3<3.0,>=2.4.0->sb3_contrib<3.0,>=2.5.0a0->rl_zoo3==2.5.0a1) (12.1.105)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3<3.0,>=2.4.0->sb3_contrib<3.0,>=2.5.0a0->rl_zoo3==2.5.0a1) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3<3.0,>=2.4.0->sb3_contrib<3.0,>=2.5.0a0->rl_zoo3==2.5.0a1) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.13->stable-baselines3<3.0,>=2.4.0->sb3_contrib<3.0,>=2.5.0a0->rl_zoo3==2.5.0a1) (12.6.85)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.13->stable-baselines3<3.0,>=2.4.0->sb3_contrib<3.0,>=2.5.0a0->rl_zoo3==2.5.0a1) (1.3.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.11/dist-packages (from Mako->alembic>=1.5.0->optuna>=3.0->rl_zoo3==2.5.0a1) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3<3.0,>=2.4.0->sb3_contrib<3.0,>=2.5.0a0->rl_zoo3==2.5.0a1) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3<3.0,>=2.4.0->sb3_contrib<3.0,>=2.5.0a0->rl_zoo3==2.5.0a1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3<3.0,>=2.4.0->sb3_contrib<3.0,>=2.5.0a0->rl_zoo3==2.5.0a1) (4.55.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3<3.0,>=2.4.0->sb3_contrib<3.0,>=2.5.0a0->rl_zoo3==2.5.0a1) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3<3.0,>=2.4.0->sb3_contrib<3.0,>=2.5.0a0->rl_zoo3==2.5.0a1) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3<3.0,>=2.4.0->sb3_contrib<3.0,>=2.5.0a0->rl_zoo3==2.5.0a1) (3.2.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->stable-baselines3<3.0,>=2.4.0->sb3_contrib<3.0,>=2.5.0a0->rl_zoo3==2.5.0a1) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.5.0a1) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.5.0a1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.5.0a1) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.5.0a1) (2024.12.14)
# Downloading gymnasium-1.0.0-py3-none-any.whl (958 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 958.1/958.1 kB 18.0 MB/s eta 0:00:00
# Downloading huggingface_sb3-3.0-py3-none-any.whl (9.7 kB)
# Downloading optuna-4.2.0-py3-none-any.whl (383 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.4/383.4 kB 29.9 MB/s eta 0:00:00
# Downloading pytablewriter-1.2.1-py3-none-any.whl (91 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.1/91.1 kB 8.0 MB/s eta 0:00:00
# Downloading sb3_contrib-2.5.0a0-py3-none-any.whl (92 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 kB 9.1 MB/s eta 0:00:00
# Downloading Shimmy-2.0.0-py3-none-any.whl (30 kB)
# Downloading alembic-1.14.1-py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.6/233.6 kB 21.3 MB/s eta 0:00:00
# Downloading DataProperty-1.1.0-py3-none-any.whl (27 kB)
# Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Downloading mbstrdecoder-1.1.4-py3-none-any.whl (7.9 kB)
# Downloading pathvalidate-3.2.3-py3-none-any.whl (24 kB)
# Downloading stable_baselines3-2.4.1-py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.0/184.0 kB 17.2 MB/s eta 0:00:00
# Downloading tabledata-1.3.4-py3-none-any.whl (11 kB)
# Downloading tcolorpy-0.1.7-py3-none-any.whl (8.1 kB)
# Downloading typepy-1.3.4-py3-none-any.whl (31 kB)
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Downloading Mako-1.3.8-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 7.9 MB/s eta 0:00:00
# Building wheels for collected packages: rl_zoo3
#   Building wheel for rl_zoo3 (pyproject.toml) ... done
#   Created wheel for rl_zoo3: filename=rl_zoo3-2.5.0a1-py3-none-any.whl size=77339 sha256=1872deaddf0e0fa92b4692dff4f48a819e0be3eff7d1451115b18c64cefb279b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-inb9j3w4/wheels/79/a7/a1/afc7c6c739a99c02b2cba585d219d453a80ab2bff20fb6526f
# Successfully built rl_zoo3
# Installing collected packages: farama-notifications, tcolorpy, pathvalidate, mbstrdecoder, Mako, gymnasium, colorlog, typepy, shimmy, alembic, optuna, huggingface_sb3, stable-baselines3, DataProperty, tabledata, sb3_contrib, pytablewriter, rl_zoo3
# Successfully installed DataProperty-1.1.0 Mako-1.3.8 alembic-1.14.1 colorlog-6.9.0 farama-notifications-0.0.4 gymnasium-1.0.0 huggingface_sb3-3.0 mbstrdecoder-1.1.4 optuna-4.2.0 pathvalidate-3.2.3 pytablewriter-1.2.1 rl_zoo3-2.5.0a1 sb3_contrib-2.5.0a0 shimmy-2.0.0 stable-baselines3-2.4.1 tabledata-1.3.4 tcolorpy-0.1.7 typepy-1.3.4

# %%
# !apt-get install swig cmake ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# cmake is already the newest version (3.22.1-1ubuntu1.22.04.2).
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# The following additional packages will be installed:
#   swig4.0
# Suggested packages:
#   swig-doc swig-examples swig4.0-examples swig4.0-doc
# The following NEW packages will be installed:
#   swig swig4.0
# 0 upgraded, 2 newly installed, 0 to remove and 49 not upgraded.
# Need to get 1,116 kB of archives.
# After this operation, 5,542 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig4.0 amd64 4.0.2-1ubuntu1 [1,110 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig all 4.0.2-1ubuntu1 [5,632 B]
# Fetched 1,116 kB in 1s (1,715 kB/s)
# Selecting previously unselected package swig4.0.
# (Reading database ... 124574 files and directories currently installed.)
# Preparing to unpack .../swig4.0_4.0.2-1ubuntu1_amd64.deb ...
# Unpacking swig4.0 (4.0.2-1ubuntu1) ...
# Selecting previously unselected package swig.
# Preparing to unpack .../swig_4.0.2-1ubuntu1_all.deb ...
# Unpacking swig (4.0.2-1ubuntu1) ...
# Setting up swig4.0 (4.0.2-1ubuntu1) ...
# Setting up swig (4.0.2-1ubuntu1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %% [markdown]
# To be able to use Atari games in Gymnasium we need to install atari package. And accept-rom-license to download the rom files (games files).

# %%
# !pip install gymnasium[atari]
# !pip install gymnasium[accept-rom-license]
# Out:
# Requirement already satisfied: gymnasium[atari] in /usr/local/lib/python3.11/dist-packages (1.0.0)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[atari]) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[atari]) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[atari]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium[atari]) (0.0.4)
# Collecting ale-py>=0.9 (from gymnasium[atari])
#   Downloading ale_py-0.10.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.6 kB)
# Downloading ale_py-0.10.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 27.6 MB/s eta 0:00:00
# Installing collected packages: ale-py
# Successfully installed ale-py-0.10.1
# Requirement already satisfied: gymnasium[accept-rom-license] in /usr/local/lib/python3.11/dist-packages (1.0.0)
# WARNING: gymnasium 1.0.0 does not provide the extra 'accept-rom-license'
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[accept-rom-license]) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[accept-rom-license]) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[accept-rom-license]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium[accept-rom-license]) (0.0.4)

# %% [markdown]
# ## Create a virtual display 🔽
#
# During the notebook, we'll need to generate a replay video. To do so, with colab, **we need to have a virtual screen to be able to render the environment** (and thus record the frames).
#
# Hence the following cell will install the librairies and create and run a virtual screen 🖥

# %%
# %%capture
# !apt install python-opengl
# !apt install xvfb
# !pip3 install pyvirtualdisplay

# %%
# Virtual display
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %% [markdown]
# ## Train our Deep Q-Learning Agent to Play Space Invaders 👾
#
# To train an agent with RL-Baselines3-Zoo, we just need to do two things:
#
# 1. Create a hyperparameter config file that will contain our training hyperparameters called `dqn.yml`.
#
# This is a template example:
#
# ```
# SpaceInvadersNoFrameskip-v4:
#   env_wrapper:
#     - stable_baselines3.common.atari_wrappers.AtariWrapper
#   frame_stack: 4
#   policy: 'CnnPolicy'
#   n_timesteps: !!float 1e6
#   buffer_size: 100000
#   learning_rate: !!float 1e-4
#   batch_size: 32
#   learning_starts: 100000
#   target_update_interval: 1000
#   train_freq: 4
#   gradient_steps: 1
#   exploration_fraction: 0.1
#   exploration_final_eps: 0.01
#   # If True, you need to deactivate handle_timeout_termination
#   # in the replay_buffer_kwargs
#   optimize_memory_usage: False
# ```

# %% [markdown]
# Here we see that:
# - We use the `Atari Wrapper` that preprocess the input (Frame reduction ,grayscale, stack 4 frames)
# - We use `CnnPolicy`, since we use Convolutional layers to process the frames
# - We train it for 10 million `n_timesteps`
# - Memory (Experience Replay) size is 100000, aka the amount of experience steps you saved to train again your agent with.
#
# 💡 My advice is to **reduce the training timesteps to 1M,** which will take about 90 minutes on a P100. `!nvidia-smi` will tell you what GPU you're using. At 10 million steps, this will take about 9 hours, which could likely result in Colab timing out. I recommend running this on your local computer (or somewhere else). Just click on: `File>Download`.

# %% [markdown]
# In terms of hyperparameters optimization, my advice is to focus on these 3 hyperparameters:
# - `learning_rate`
# - `buffer_size (Experience Memory size)`
# - `batch_size`
#
# As a good practice, you need to **check the documentation to understand what each hyperparameters does**: https://stable-baselines3.readthedocs.io/en/master/modules/dqn.html#parameters

# %% [markdown]
# 2. We start the training and save the models on `logs` folder 📁
#
# - Define the algorithm after `--algo`, where we save the model after `-f` and where the hyperparameter config is after `-c`.

# %%
# !python -m rl_zoo3.train --algo dqn --env SpaceInvadersNoFrameskip-v4  -f /content/logs/  -c /content/dqn.yml
# Out:
# Streaming output truncated to the last 5000 lines.
# Eval num_timesteps=550000, episode_reward=531.00 +/- 123.06
# Episode length: 3835.00 +/- 517.74
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.84e+03 |
# |    mean_reward      | 531      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 550000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0326   |
# |    n_updates        | 112499   |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.19e+03 |
# |    ep_rew_mean      | 418      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2704     |
# |    fps              | 280      |
# |    time_elapsed     | 1965     |
# |    total_timesteps  | 550740   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0202   |
# |    n_updates        | 112684   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.19e+03 |
# |    ep_rew_mean      | 420      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2708     |
# |    fps              | 280      |
# |    time_elapsed     | 1969     |
# |    total_timesteps  | 551835   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0144   |
# |    n_updates        | 112958   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.2e+03  |
# |    ep_rew_mean      | 422      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2712     |
# |    fps              | 280      |
# |    time_elapsed     | 1972     |
# |    total_timesteps  | 552572   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.013    |
# |    n_updates        | 113142   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.22e+03 |
# |    ep_rew_mean      | 426      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2716     |
# |    fps              | 280      |
# |    time_elapsed     | 1977     |
# |    total_timesteps  | 553977   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0175   |
# |    n_updates        | 113494   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.25e+03 |
# |    ep_rew_mean      | 435      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2720     |
# |    fps              | 280      |
# |    time_elapsed     | 1984     |
# |    total_timesteps  | 555965   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0317   |
# |    n_updates        | 113991   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.25e+03 |
# |    ep_rew_mean      | 435      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2724     |
# |    fps              | 280      |
# |    time_elapsed     | 1988     |
# |    total_timesteps  | 557201   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.034    |
# |    n_updates        | 114300   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.26e+03 |
# |    ep_rew_mean      | 436      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2728     |
# |    fps              | 280      |
# |    time_elapsed     | 1992     |
# |    total_timesteps  | 558255   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0543   |
# |    n_updates        | 114563   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.27e+03 |
# |    ep_rew_mean      | 438      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2732     |
# |    fps              | 280      |
# |    time_elapsed     | 1996     |
# |    total_timesteps  | 559385   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0423   |
# |    n_updates        | 114846   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.26e+03 |
# |    ep_rew_mean      | 442      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2736     |
# |    fps              | 280      |
# |    time_elapsed     | 2000     |
# |    total_timesteps  | 560461   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0737   |
# |    n_updates        | 115115   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.27e+03 |
# |    ep_rew_mean      | 443      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2740     |
# |    fps              | 280      |
# |    time_elapsed     | 2005     |
# |    total_timesteps  | 562093   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0252   |
# |    n_updates        | 115523   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.27e+03 |
# |    ep_rew_mean      | 443      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2744     |
# |    fps              | 280      |
# |    time_elapsed     | 2008     |
# |    total_timesteps  | 562936   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0102   |
# |    n_updates        | 115733   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.27e+03 |
# |    ep_rew_mean      | 441      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2748     |
# |    fps              | 280      |
# |    time_elapsed     | 2013     |
# |    total_timesteps  | 564104   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0282   |
# |    n_updates        | 116025   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.28e+03 |
# |    ep_rew_mean      | 441      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2752     |
# |    fps              | 280      |
# |    time_elapsed     | 2017     |
# |    total_timesteps  | 565249   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0244   |
# |    n_updates        | 116312   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.3e+03  |
# |    ep_rew_mean      | 445      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2756     |
# |    fps              | 280      |
# |    time_elapsed     | 2021     |
# |    total_timesteps  | 566399   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0157   |
# |    n_updates        | 116599   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.3e+03  |
# |    ep_rew_mean      | 448      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2760     |
# |    fps              | 280      |
# |    time_elapsed     | 2027     |
# |    total_timesteps  | 568041   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0225   |
# |    n_updates        | 117010   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.29e+03 |
# |    ep_rew_mean      | 450      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2764     |
# |    fps              | 280      |
# |    time_elapsed     | 2032     |
# |    total_timesteps  | 569382   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0164   |
# |    n_updates        | 117345   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.29e+03 |
# |    ep_rew_mean      | 450      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2768     |
# |    fps              | 280      |
# |    time_elapsed     | 2035     |
# |    total_timesteps  | 570306   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0272   |
# |    n_updates        | 117576   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.29e+03 |
# |    ep_rew_mean      | 450      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2772     |
# |    fps              | 280      |
# |    time_elapsed     | 2040     |
# |    total_timesteps  | 571470   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0324   |
# |    n_updates        | 117867   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.3e+03  |
# |    ep_rew_mean      | 450      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2776     |
# |    fps              | 280      |
# |    time_elapsed     | 2043     |
# |    total_timesteps  | 572569   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0192   |
# |    n_updates        | 118142   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.29e+03 |
# |    ep_rew_mean      | 447      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2780     |
# |    fps              | 280      |
# |    time_elapsed     | 2046     |
# |    total_timesteps  | 573373   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0177   |
# |    n_updates        | 118343   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.26e+03 |
# |    ep_rew_mean      | 439      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2784     |
# |    fps              | 280      |
# |    time_elapsed     | 2048     |
# |    total_timesteps  | 573977   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0854   |
# |    n_updates        | 118494   |
# ----------------------------------
# Eval num_timesteps=575000, episode_reward=440.00 +/- 73.21
# Episode length: 3346.80 +/- 494.40
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.35e+03 |
# |    mean_reward      | 440      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 575000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.015    |
# |    n_updates        | 118749   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.27e+03 |
# |    ep_rew_mean      | 440      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2788     |
# |    fps              | 278      |
# |    time_elapsed     | 2061     |
# |    total_timesteps  | 575223   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0179   |
# |    n_updates        | 118805   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.29e+03 |
# |    ep_rew_mean      | 442      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2792     |
# |    fps              | 278      |
# |    time_elapsed     | 2069     |
# |    total_timesteps  | 576754   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0198   |
# |    n_updates        | 119188   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.29e+03 |
# |    ep_rew_mean      | 444      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2796     |
# |    fps              | 278      |
# |    time_elapsed     | 2071     |
# |    total_timesteps  | 577407   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0343   |
# |    n_updates        | 119351   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.29e+03 |
# |    ep_rew_mean      | 443      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2800     |
# |    fps              | 278      |
# |    time_elapsed     | 2077     |
# |    total_timesteps  | 579085   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0222   |
# |    n_updates        | 119771   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.28e+03 |
# |    ep_rew_mean      | 438      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2804     |
# |    fps              | 278      |
# |    time_elapsed     | 2079     |
# |    total_timesteps  | 579646   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0206   |
# |    n_updates        | 119911   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.28e+03 |
# |    ep_rew_mean      | 439      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2808     |
# |    fps              | 278      |
# |    time_elapsed     | 2083     |
# |    total_timesteps  | 580724   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0189   |
# |    n_updates        | 120180   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.3e+03  |
# |    ep_rew_mean      | 442      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2812     |
# |    fps              | 278      |
# |    time_elapsed     | 2088     |
# |    total_timesteps  | 582170   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0479   |
# |    n_updates        | 120542   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.32e+03 |
# |    ep_rew_mean      | 449      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2816     |
# |    fps              | 278      |
# |    time_elapsed     | 2092     |
# |    total_timesteps  | 583340   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0386   |
# |    n_updates        | 120834   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.32e+03 |
# |    ep_rew_mean      | 446      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2820     |
# |    fps              | 278      |
# |    time_elapsed     | 2096     |
# |    total_timesteps  | 584516   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0385   |
# |    n_updates        | 121128   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.31e+03 |
# |    ep_rew_mean      | 449      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2824     |
# |    fps              | 278      |
# |    time_elapsed     | 2102     |
# |    total_timesteps  | 586077   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0285   |
# |    n_updates        | 121519   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.32e+03 |
# |    ep_rew_mean      | 447      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2828     |
# |    fps              | 278      |
# |    time_elapsed     | 2107     |
# |    total_timesteps  | 587292   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0244   |
# |    n_updates        | 121822   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.31e+03 |
# |    ep_rew_mean      | 449      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2832     |
# |    fps              | 278      |
# |    time_elapsed     | 2111     |
# |    total_timesteps  | 588503   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0293   |
# |    n_updates        | 122125   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.29e+03 |
# |    ep_rew_mean      | 447      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2836     |
# |    fps              | 278      |
# |    time_elapsed     | 2113     |
# |    total_timesteps  | 589125   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0427   |
# |    n_updates        | 122281   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.3e+03  |
# |    ep_rew_mean      | 447      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2840     |
# |    fps              | 278      |
# |    time_elapsed     | 2118     |
# |    total_timesteps  | 590454   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0125   |
# |    n_updates        | 122613   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.3e+03  |
# |    ep_rew_mean      | 447      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2844     |
# |    fps              | 278      |
# |    time_elapsed     | 2122     |
# |    total_timesteps  | 591539   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0227   |
# |    n_updates        | 122884   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.29e+03 |
# |    ep_rew_mean      | 444      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2848     |
# |    fps              | 278      |
# |    time_elapsed     | 2124     |
# |    total_timesteps  | 592199   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00958  |
# |    n_updates        | 123049   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.31e+03 |
# |    ep_rew_mean      | 446      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2852     |
# |    fps              | 278      |
# |    time_elapsed     | 2128     |
# |    total_timesteps  | 593413   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0303   |
# |    n_updates        | 123353   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.3e+03  |
# |    ep_rew_mean      | 448      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2856     |
# |    fps              | 278      |
# |    time_elapsed     | 2133     |
# |    total_timesteps  | 594651   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0367   |
# |    n_updates        | 123662   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.29e+03 |
# |    ep_rew_mean      | 446      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2860     |
# |    fps              | 278      |
# |    time_elapsed     | 2137     |
# |    total_timesteps  | 595677   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0985   |
# |    n_updates        | 123919   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.3e+03  |
# |    ep_rew_mean      | 447      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2864     |
# |    fps              | 278      |
# |    time_elapsed     | 2143     |
# |    total_timesteps  | 597454   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0156   |
# |    n_updates        | 124363   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.29e+03 |
# |    ep_rew_mean      | 445      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2868     |
# |    fps              | 278      |
# |    time_elapsed     | 2147     |
# |    total_timesteps  | 598417   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0101   |
# |    n_updates        | 124604   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.29e+03 |
# |    ep_rew_mean      | 445      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2872     |
# |    fps              | 278      |
# |    time_elapsed     | 2151     |
# |    total_timesteps  | 599765   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0453   |
# |    n_updates        | 124941   |
# ----------------------------------
# Eval num_timesteps=600000, episode_reward=679.00 +/- 54.99
# Episode length: 3866.80 +/- 574.59
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.87e+03 |
# |    mean_reward      | 679      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 600000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0171   |
# |    n_updates        | 124999   |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.31e+03 |
# |    ep_rew_mean      | 450      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2876     |
# |    fps              | 277      |
# |    time_elapsed     | 2166     |
# |    total_timesteps  | 600929   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0201   |
# |    n_updates        | 125232   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.32e+03 |
# |    ep_rew_mean      | 449      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2880     |
# |    fps              | 277      |
# |    time_elapsed     | 2171     |
# |    total_timesteps  | 602337   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0639   |
# |    n_updates        | 125584   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.3e+03  |
# |    ep_rew_mean      | 447      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2884     |
# |    fps              | 277      |
# |    time_elapsed     | 2175     |
# |    total_timesteps  | 603289   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0201   |
# |    n_updates        | 125822   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.29e+03 |
# |    ep_rew_mean      | 447      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2888     |
# |    fps              | 277      |
# |    time_elapsed     | 2177     |
# |    total_timesteps  | 604008   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0208   |
# |    n_updates        | 126001   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.32e+03 |
# |    ep_rew_mean      | 451      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2892     |
# |    fps              | 277      |
# |    time_elapsed     | 2181     |
# |    total_timesteps  | 605094   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0427   |
# |    n_updates        | 126273   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.31e+03 |
# |    ep_rew_mean      | 450      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2896     |
# |    fps              | 277      |
# |    time_elapsed     | 2187     |
# |    total_timesteps  | 606662   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0308   |
# |    n_updates        | 126665   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.29e+03 |
# |    ep_rew_mean      | 446      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2900     |
# |    fps              | 277      |
# |    time_elapsed     | 2189     |
# |    total_timesteps  | 607198   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00961  |
# |    n_updates        | 126799   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.28e+03 |
# |    ep_rew_mean      | 446      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2904     |
# |    fps              | 277      |
# |    time_elapsed     | 2192     |
# |    total_timesteps  | 608228   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0152   |
# |    n_updates        | 127056   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.28e+03 |
# |    ep_rew_mean      | 448      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2908     |
# |    fps              | 277      |
# |    time_elapsed     | 2196     |
# |    total_timesteps  | 609380   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0197   |
# |    n_updates        | 127344   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.3e+03  |
# |    ep_rew_mean      | 455      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2912     |
# |    fps              | 277      |
# |    time_elapsed     | 2202     |
# |    total_timesteps  | 610841   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0214   |
# |    n_updates        | 127710   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.3e+03  |
# |    ep_rew_mean      | 456      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2916     |
# |    fps              | 277      |
# |    time_elapsed     | 2206     |
# |    total_timesteps  | 612038   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0301   |
# |    n_updates        | 128009   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.32e+03 |
# |    ep_rew_mean      | 458      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2920     |
# |    fps              | 277      |
# |    time_elapsed     | 2211     |
# |    total_timesteps  | 613291   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.013    |
# |    n_updates        | 128322   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.31e+03 |
# |    ep_rew_mean      | 456      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2924     |
# |    fps              | 277      |
# |    time_elapsed     | 2218     |
# |    total_timesteps  | 615430   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0242   |
# |    n_updates        | 128857   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.31e+03 |
# |    ep_rew_mean      | 456      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2928     |
# |    fps              | 277      |
# |    time_elapsed     | 2221     |
# |    total_timesteps  | 616262   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0304   |
# |    n_updates        | 129065   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.3e+03  |
# |    ep_rew_mean      | 454      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2932     |
# |    fps              | 277      |
# |    time_elapsed     | 2225     |
# |    total_timesteps  | 617207   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0162   |
# |    n_updates        | 129301   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.29e+03 |
# |    ep_rew_mean      | 453      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2936     |
# |    fps              | 277      |
# |    time_elapsed     | 2228     |
# |    total_timesteps  | 618190   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0258   |
# |    n_updates        | 129547   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.29e+03 |
# |    ep_rew_mean      | 452      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2940     |
# |    fps              | 277      |
# |    time_elapsed     | 2232     |
# |    total_timesteps  | 619369   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0573   |
# |    n_updates        | 129842   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.28e+03 |
# |    ep_rew_mean      | 448      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2944     |
# |    fps              | 277      |
# |    time_elapsed     | 2238     |
# |    total_timesteps  | 620748   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0244   |
# |    n_updates        | 130186   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.31e+03 |
# |    ep_rew_mean      | 455      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2948     |
# |    fps              | 277      |
# |    time_elapsed     | 2242     |
# |    total_timesteps  | 621881   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00682  |
# |    n_updates        | 130470   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.32e+03 |
# |    ep_rew_mean      | 458      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2952     |
# |    fps              | 277      |
# |    time_elapsed     | 2247     |
# |    total_timesteps  | 623228   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0279   |
# |    n_updates        | 130806   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.31e+03 |
# |    ep_rew_mean      | 456      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2956     |
# |    fps              | 277      |
# |    time_elapsed     | 2251     |
# |    total_timesteps  | 624053   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0396   |
# |    n_updates        | 131013   |
# ----------------------------------
# Eval num_timesteps=625000, episode_reward=572.00 +/- 278.67
# Episode length: 3935.40 +/- 1091.46
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.94e+03 |
# |    mean_reward      | 572      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 625000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0505   |
# |    n_updates        | 131249   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.32e+03 |
# |    ep_rew_mean      | 457      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2960     |
# |    fps              | 275      |
# |    time_elapsed     | 2266     |
# |    total_timesteps  | 625296   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0296   |
# |    n_updates        | 131323   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.33e+03 |
# |    ep_rew_mean      | 460      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2964     |
# |    fps              | 275      |
# |    time_elapsed     | 2272     |
# |    total_timesteps  | 627045   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00514  |
# |    n_updates        | 131761   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.33e+03 |
# |    ep_rew_mean      | 459      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2968     |
# |    fps              | 275      |
# |    time_elapsed     | 2276     |
# |    total_timesteps  | 628323   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0189   |
# |    n_updates        | 132080   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.34e+03 |
# |    ep_rew_mean      | 460      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2972     |
# |    fps              | 275      |
# |    time_elapsed     | 2282     |
# |    total_timesteps  | 629741   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0179   |
# |    n_updates        | 132435   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.34e+03 |
# |    ep_rew_mean      | 459      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2976     |
# |    fps              | 275      |
# |    time_elapsed     | 2286     |
# |    total_timesteps  | 631003   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0312   |
# |    n_updates        | 132750   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.34e+03 |
# |    ep_rew_mean      | 458      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2980     |
# |    fps              | 275      |
# |    time_elapsed     | 2288     |
# |    total_timesteps  | 631748   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0279   |
# |    n_updates        | 132936   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.34e+03 |
# |    ep_rew_mean      | 458      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2984     |
# |    fps              | 275      |
# |    time_elapsed     | 2294     |
# |    total_timesteps  | 633138   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0129   |
# |    n_updates        | 133284   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.38e+03 |
# |    ep_rew_mean      | 463      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2988     |
# |    fps              | 276      |
# |    time_elapsed     | 2300     |
# |    total_timesteps  | 635089   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0145   |
# |    n_updates        | 133772   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.37e+03 |
# |    ep_rew_mean      | 460      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2992     |
# |    fps              | 275      |
# |    time_elapsed     | 2305     |
# |    total_timesteps  | 636124   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0341   |
# |    n_updates        | 134030   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.38e+03 |
# |    ep_rew_mean      | 459      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2996     |
# |    fps              | 275      |
# |    time_elapsed     | 2310     |
# |    total_timesteps  | 637622   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0177   |
# |    n_updates        | 134405   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.4e+03  |
# |    ep_rew_mean      | 460      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3000     |
# |    fps              | 275      |
# |    time_elapsed     | 2318     |
# |    total_timesteps  | 639752   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0257   |
# |    n_updates        | 134937   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.41e+03 |
# |    ep_rew_mean      | 462      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3004     |
# |    fps              | 276      |
# |    time_elapsed     | 2323     |
# |    total_timesteps  | 641362   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0302   |
# |    n_updates        | 135340   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.43e+03 |
# |    ep_rew_mean      | 466      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3008     |
# |    fps              | 276      |
# |    time_elapsed     | 2328     |
# |    total_timesteps  | 642829   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0189   |
# |    n_updates        | 135707   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.43e+03 |
# |    ep_rew_mean      | 469      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3012     |
# |    fps              | 276      |
# |    time_elapsed     | 2335     |
# |    total_timesteps  | 644518   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0226   |
# |    n_updates        | 136129   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.43e+03 |
# |    ep_rew_mean      | 468      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3016     |
# |    fps              | 276      |
# |    time_elapsed     | 2337     |
# |    total_timesteps  | 645168   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0172   |
# |    n_updates        | 136291   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.42e+03 |
# |    ep_rew_mean      | 472      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3020     |
# |    fps              | 276      |
# |    time_elapsed     | 2342     |
# |    total_timesteps  | 646650   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0207   |
# |    n_updates        | 136662   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.41e+03 |
# |    ep_rew_mean      | 470      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3024     |
# |    fps              | 276      |
# |    time_elapsed     | 2347     |
# |    total_timesteps  | 647982   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0446   |
# |    n_updates        | 136995   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.43e+03 |
# |    ep_rew_mean      | 474      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3028     |
# |    fps              | 276      |
# |    time_elapsed     | 2353     |
# |    total_timesteps  | 649776   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0392   |
# |    n_updates        | 137443   |
# ----------------------------------
# Eval num_timesteps=650000, episode_reward=502.00 +/- 192.50
# Episode length: 3101.80 +/- 584.70
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.1e+03  |
# |    mean_reward      | 502      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 650000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00828  |
# |    n_updates        | 137499   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.43e+03 |
# |    ep_rew_mean      | 477      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3032     |
# |    fps              | 275      |
# |    time_elapsed     | 2370     |
# |    total_timesteps  | 652008   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.025    |
# |    n_updates        | 138001   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.44e+03 |
# |    ep_rew_mean      | 478      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3036     |
# |    fps              | 275      |
# |    time_elapsed     | 2373     |
# |    total_timesteps  | 652829   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0117   |
# |    n_updates        | 138207   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.45e+03 |
# |    ep_rew_mean      | 479      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3040     |
# |    fps              | 275      |
# |    time_elapsed     | 2377     |
# |    total_timesteps  | 653931   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0162   |
# |    n_updates        | 138482   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.45e+03 |
# |    ep_rew_mean      | 477      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3044     |
# |    fps              | 275      |
# |    time_elapsed     | 2380     |
# |    total_timesteps  | 655090   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0153   |
# |    n_updates        | 138772   |
# ----------------------------------
# ...
# |    learning_rate    | 0.0001   |
# |    loss             | 0.01     |
# |    n_updates        | 212973   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.73e+03 |
# |    ep_rew_mean      | 545      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3848     |
# |    fps              | 266      |
# |    time_elapsed     | 3581     |
# |    total_timesteps  | 954023   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0178   |
# |    n_updates        | 213505   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.75e+03 |
# |    ep_rew_mean      | 550      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3852     |
# |    fps              | 266      |
# |    time_elapsed     | 3587     |
# |    total_timesteps  | 955829   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0207   |
# |    n_updates        | 213957   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.75e+03 |
# |    ep_rew_mean      | 552      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3856     |
# |    fps              | 266      |
# |    time_elapsed     | 3595     |
# |    total_timesteps  | 958014   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0171   |
# |    n_updates        | 214503   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.74e+03 |
# |    ep_rew_mean      | 550      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3860     |
# |    fps              | 266      |
# |    time_elapsed     | 3602     |
# |    total_timesteps  | 959958   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0115   |
# |    n_updates        | 214989   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.77e+03 |
# |    ep_rew_mean      | 552      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3864     |
# |    fps              | 266      |
# |    time_elapsed     | 3606     |
# |    total_timesteps  | 961208   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0199   |
# |    n_updates        | 215301   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.76e+03 |
# |    ep_rew_mean      | 553      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3868     |
# |    fps              | 266      |
# |    time_elapsed     | 3613     |
# |    total_timesteps  | 963053   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0249   |
# |    n_updates        | 215763   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.78e+03 |
# |    ep_rew_mean      | 557      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3872     |
# |    fps              | 266      |
# |    time_elapsed     | 3622     |
# |    total_timesteps  | 965548   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0235   |
# |    n_updates        | 216386   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.78e+03 |
# |    ep_rew_mean      | 557      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3876     |
# |    fps              | 266      |
# |    time_elapsed     | 3626     |
# |    total_timesteps  | 966713   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0421   |
# |    n_updates        | 216678   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.79e+03 |
# |    ep_rew_mean      | 556      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3880     |
# |    fps              | 266      |
# |    time_elapsed     | 3632     |
# |    total_timesteps  | 968295   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0412   |
# |    n_updates        | 217073   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.79e+03 |
# |    ep_rew_mean      | 556      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3884     |
# |    fps              | 266      |
# |    time_elapsed     | 3637     |
# |    total_timesteps  | 969781   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.029    |
# |    n_updates        | 217445   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.79e+03 |
# |    ep_rew_mean      | 555      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3888     |
# |    fps              | 266      |
# |    time_elapsed     | 3642     |
# |    total_timesteps  | 971086   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0116   |
# |    n_updates        | 217771   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.79e+03 |
# |    ep_rew_mean      | 559      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3892     |
# |    fps              | 266      |
# |    time_elapsed     | 3648     |
# |    total_timesteps  | 972799   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0243   |
# |    n_updates        | 218199   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.79e+03 |
# |    ep_rew_mean      | 563      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3896     |
# |    fps              | 266      |
# |    time_elapsed     | 3653     |
# |    total_timesteps  | 974174   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0119   |
# |    n_updates        | 218543   |
# ----------------------------------
# Eval num_timesteps=975000, episode_reward=599.00 +/- 105.00
# Episode length: 3637.80 +/- 391.66
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.64e+03 |
# |    mean_reward      | 599      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 975000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0168   |
# |    n_updates        | 218749   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.82e+03 |
# |    ep_rew_mean      | 570      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3900     |
# |    fps              | 265      |
# |    time_elapsed     | 3669     |
# |    total_timesteps  | 975911   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0274   |
# |    n_updates        | 218977   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.82e+03 |
# |    ep_rew_mean      | 570      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3904     |
# |    fps              | 265      |
# |    time_elapsed     | 3677     |
# |    total_timesteps  | 977813   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0307   |
# |    n_updates        | 219453   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.82e+03 |
# |    ep_rew_mean      | 569      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3908     |
# |    fps              | 265      |
# |    time_elapsed     | 3683     |
# |    total_timesteps  | 979405   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00921  |
# |    n_updates        | 219851   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.86e+03 |
# |    ep_rew_mean      | 574      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3912     |
# |    fps              | 265      |
# |    time_elapsed     | 3692     |
# |    total_timesteps  | 982018   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0187   |
# |    n_updates        | 220504   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.88e+03 |
# |    ep_rew_mean      | 578      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3916     |
# |    fps              | 266      |
# |    time_elapsed     | 3700     |
# |    total_timesteps  | 984274   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0242   |
# |    n_updates        | 221068   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.89e+03 |
# |    ep_rew_mean      | 580      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3920     |
# |    fps              | 266      |
# |    time_elapsed     | 3703     |
# |    total_timesteps  | 985145   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.051    |
# |    n_updates        | 221286   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.88e+03 |
# |    ep_rew_mean      | 575      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3924     |
# |    fps              | 266      |
# |    time_elapsed     | 3707     |
# |    total_timesteps  | 986289   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.011    |
# |    n_updates        | 221572   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.89e+03 |
# |    ep_rew_mean      | 573      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3928     |
# |    fps              | 266      |
# |    time_elapsed     | 3714     |
# |    total_timesteps  | 988369   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0278   |
# |    n_updates        | 222092   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.88e+03 |
# |    ep_rew_mean      | 573      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3932     |
# |    fps              | 266      |
# |    time_elapsed     | 3721     |
# |    total_timesteps  | 990097   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0371   |
# |    n_updates        | 222524   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.9e+03  |
# |    ep_rew_mean      | 577      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3936     |
# |    fps              | 266      |
# |    time_elapsed     | 3725     |
# |    total_timesteps  | 991329   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0116   |
# |    n_updates        | 222832   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.91e+03 |
# |    ep_rew_mean      | 584      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3940     |
# |    fps              | 266      |
# |    time_elapsed     | 3733     |
# |    total_timesteps  | 993369   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0132   |
# |    n_updates        | 223342   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.9e+03  |
# |    ep_rew_mean      | 583      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3944     |
# |    fps              | 266      |
# |    time_elapsed     | 3736     |
# |    total_timesteps  | 994366   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0282   |
# |    n_updates        | 223591   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.89e+03 |
# |    ep_rew_mean      | 582      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3948     |
# |    fps              | 266      |
# |    time_elapsed     | 3741     |
# |    total_timesteps  | 995940   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0365   |
# |    n_updates        | 223984   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.9e+03  |
# |    ep_rew_mean      | 584      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3952     |
# |    fps              | 266      |
# |    time_elapsed     | 3749     |
# |    total_timesteps  | 997996   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0133   |
# |    n_updates        | 224498   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.91e+03 |
# |    ep_rew_mean      | 584      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3956     |
# |    fps              | 266      |
# |    time_elapsed     | 3753     |
# |    total_timesteps  | 999303   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0455   |
# |    n_updates        | 224825   |
# ----------------------------------
# Eval num_timesteps=1000000, episode_reward=580.00 +/- 52.54
# Episode length: 3481.60 +/- 264.70
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.48e+03 |
# |    mean_reward      | 580      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 1000000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0224   |
# |    n_updates        | 224999   |
# ----------------------------------
# Saving to /content/logs//dqn/SpaceInvadersNoFrameskip-v4_1

# %% [markdown]
# #### Solution

# %% [markdown]
# ## Let's evaluate our agent 👀
# - RL-Baselines3-Zoo provides `enjoy.py`, a python script to evaluate our agent. In most RL libraries, we call the evaluation script `enjoy.py`.
# - Let's evaluate it for 5000 timesteps 🔥

# %%
# !python -m rl_zoo3.enjoy  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --no-render  --n-timesteps 5000 --folder logs/
# Out:
# 2025-01-25 12:00:39.809363: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-25 12:00:39.831648: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-25 12:00:39.841844: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-25 12:00:39.859722: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-25 12:00:41.067021: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Loading latest experiment, id=1
# Loading logs/dqn/SpaceInvadersNoFrameskip-v4_1/SpaceInvadersNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.10.1+unknown)
# [Powered by Stella]
# Stacking 4 frames
# Atari Episode Score: 260.00
# Atari Episode Length 3447
# Atari Episode Score: 425.00
# Atari Episode Length 4759
# Atari Episode Score: 365.00
# Atari Episode Length 4693
# Atari Episode Score: 315.00
# Atari Episode Length 3169

# %%
# !python -m rl_zoo3.enjoy  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --no-render  --n-timesteps 5000 --folder logs/
# Out:
# 2025-01-25 18:48:01.356324: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-25 18:48:01.389894: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-25 18:48:01.400093: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-25 18:48:01.422982: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-25 18:48:02.728887: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Loading latest experiment, id=1
# Loading logs/dqn/SpaceInvadersNoFrameskip-v4_1/SpaceInvadersNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.10.1+unknown)
# [Powered by Stella]
# Stacking 4 frames
# Atari Episode Score: 570.00
# Atari Episode Length 4118
# Atari Episode Score: 615.00
# Atari Episode Length 3242
# Atari Episode Score: 780.00
# Atari Episode Length 3216
# Atari Episode Score: 915.00
# Atari Episode Length 5319
# Atari Episode Score: 535.00
# Atari Episode Length 3264

# %% [markdown]
# #### Solution

# %% [markdown]
# ## Publish our trained model on the Hub 🚀
# Now that we saw we got good results after the training, we can publish our trained model on the hub 🤗 with one line of code.
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit3/space-invaders-model.gif" alt="Space Invaders model">

# %% [markdown]
# By using `rl_zoo3.push_to_hub` **you evaluate, record a replay, generate a model card of your agent and push it to the hub**.
#
# This way:
# - You can **showcase our work** 🔥
# - You can **visualize your agent playing** 👀
# - You can **share with the community an agent that others can use** 💾
# - You can **access a leaderboard 🏆 to see how well your agent is performing compared to your classmates** 👉  https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard

# %% [markdown]
# To be able to share your model with the community there are three more steps to follow:
#
# 1️⃣ (If it's not already done) create an account to HF ➡ https://huggingface.co/join
#
# 2️⃣ Sign in and then, you need to store your authentication token from the Hugging Face website.
# - Create a new token (https://huggingface.co/settings/tokens) **with write role**
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/create-token.jpg" alt="Create HF Token">

# %% [markdown]
# - Copy the token
# - Run the cell below and past the token

# %%
from huggingface_hub import notebook_login # To log to our Hugging Face account to be able to upload models to the Hub.
notebook_login()
# !git config --global credential.helper store
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# If you don't want to use a Google Colab or a Jupyter Notebook, you need to use this command instead: `huggingface-cli login`

# %% [markdown]
# 3️⃣ We're now ready to push our trained agent to the 🤗 Hub 🔥

# %% [markdown]
# Let's run push_to_hub.py file to upload our trained agent to the Hub.
#
# `--repo-name `: The name of the repo
#
# `-orga`: Your Hugging Face username
#
# `-f`: Where the trained model folder is (in our case `logs`)
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit3/select-id.png" alt="Select Id">

# %%
# !python -m rl_zoo3.push_to_hub  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --repo-name dqn-SpaceInvadersNoFrameskip-v4 -orga sanjay-906 -f logs/
# Out:
# 2025-01-25 18:48:54.435257: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-25 18:48:54.455117: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-25 18:48:54.461129: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-25 18:48:54.475062: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-25 18:48:55.543530: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Loading latest experiment, id=1
# Loading logs/dqn/SpaceInvadersNoFrameskip-v4_1/SpaceInvadersNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.10.1+unknown)
# [Powered by Stella]
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Uploading to sanjay-906/dqn-SpaceInvadersNoFrameskip-v4, make sure to have the rights
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to some
# minutes if video generation is activated. This is a work in progress: if you
# encounter a bug, please open an issue.
# Fetching 14 files:   0% 0/14 [00:00<?, ?it/s]
# README.md: 100% 2.81k/2.81k [00:00<00:00, 20.5MB/s]
#
# args.yml: 100% 1.26k/1.26k [00:00<00:00, 9.84MB/s]
#
# (…)oFrameskip-v4/_stable_baselines3_version: 100% 5.00/5.00 [00:00<00:00, 51.7kB/s]
#
# config.yml:   0% 0.00/549 [00:00<?, ?B/s]
#
# .gitattributes: 100% 1.56k/1.56k [00:00<00:00, 14.9MB/s]
# config.yml: 100% 549/549 [00:00<00:00, 158kB/s]
#
# dqn-SpaceInvadersNoFrameskip-v4.zip:   0% 0.00/27.2M [00:00<?, ?B/s]
#
# policy.optimizer.pth:   0% 0.00/13.5M [00:00<?, ?B/s]
#
#
# dqn-SpaceInvadersNoFrameskip-v4/data: 100% 208k/208k [00:00<00:00, 2.28MB/s]
#
#
#
# env_kwargs.yml: 100% 23.0/23.0 [00:00<00:00, 160kB/s]
#
#
#
# (…)ceInvadersNoFrameskip-v4/system_info.txt: 100% 260/260 [00:00<00:00, 2.15MB/s]
#
#
#
# policy.pth:   0% 0.00/13.5M [00:00<?, ?B/s]
#
#
#
# results.json: 100% 153/153 [00:00<00:00, 1.27MB/s]
#
#
#
#
# pytorch_variables.pth: 100% 864/864 [00:00<00:00, 7.37MB/s]
#
# dqn-SpaceInvadersNoFrameskip-v4.zip:  39% 10.5M/27.2M [00:00<00:00, 40.8MB/s]
#
# policy.optimizer.pth: 100% 13.5M/13.5M [00:00<00:00, 35.7MB/s]
#
#
# train_eval_metrics.zip: 100% 36.8k/36.8k [00:00<00:00, 6.69MB/s]
#
#
#
# policy.pth:  78% 10.5M/13.5M [00:00<00:00, 40.0MB/s]
# policy.pth: 100% 13.5M/13.5M [00:00<00:00, 41.1MB/s]
#
# dqn-SpaceInvadersNoFrameskip-v4.zip: 100% 27.2M/27.2M [00:00<00:00, 41.7MB/s]
# Fetching 14 files: 100% 14/14 [00:00<00:00, 15.08it/s]
# Saving model to: hub/dqn-SpaceInvadersNoFrameskip-v4/dqn-SpaceInvadersNoFrameskip-v4
# Saving video to /tmp/tmprowtazd5/-step-0-to-step-1000.mp4
# /usr/local/lib/python3.11/dist-packages/moviepy/config_defaults.py:1: DeprecationWarning: invalid escape sequence '\P'
#   """
# Moviepy - Building video /tmp/tmprowtazd5/-step-0-to-step-1000.mp4.
# Moviepy - Writing video /tmp/tmprowtazd5/-step-0-to-step-1000.mp4
#
# Moviepy - Done !
# Moviepy - video ready /tmp/tmprowtazd5/-step-0-to-step-1000.mp4
# ✘ 'DummyVecEnv' object has no attribute 'video_recorder'
# ✘ We are unable to generate a replay of your agent, the package_to_hub
# process continues
# ✘ Please open an issue at
# https://github.com/huggingface/huggingface_sb3/issues
# ℹ Pushing repo dqn-SpaceInvadersNoFrameskip-v4 to the Hugging Face
# Hub
# policy.optimizer.pth:   0% 0.00/13.5M [00:00<?, ?B/s]
# policy.pth:   0% 0.00/13.5M [00:00<?, ?B/s]
#
# dqn-SpaceInvadersNoFrameskip-v4.zip:   0% 0.00/27.2M [00:00<?, ?B/s]
#
#
# Upload 4 LFS files:   0% 0/4 [00:00<?, ?it/s]
#
#
#
# policy.optimizer.pth:  27% 3.65M/13.5M [00:00<00:00, 36.5MB/s]
# policy.pth:  34% 4.62M/13.5M [00:00<00:00, 46.2MB/s]
#
# train_eval_metrics.zip: 100% 37.1k/37.1k [00:00<00:00, 202kB/s]
#
#
# dqn-SpaceInvadersNoFrameskip-v4.zip:  17% 4.57M/27.2M [00:00<00:01, 17.6MB/s]
# policy.optimizer.pth: 100% 13.5M/13.5M [00:00<00:00, 33.0MB/s]
#
#
# dqn-SpaceInvadersNoFrameskip-v4.zip:  36% 9.68M/27.2M [00:00<00:00, 25.7MB/s]
#
#
# Upload 4 LFS files:  25% 1/4 [00:00<00:01,  1.77it/s]
#
# policy.pth: 100% 13.5M/13.5M [00:00<00:00, 17.8MB/s]
#
#
#
# Upload 4 LFS files:  50% 2/4 [00:00<00:00,  2.30it/s]
#
# dqn-SpaceInvadersNoFrameskip-v4.zip:  59% 16.0M/27.2M [00:01<00:01, 10.9MB/s]
#
# dqn-SpaceInvadersNoFrameskip-v4.zip:  83% 22.6M/27.2M [00:01<00:00, 18.5MB/s]
#
# dqn-SpaceInvadersNoFrameskip-v4.zip: 100% 27.2M/27.2M [00:01<00:00, 14.4MB/s]
#
#
#
# Upload 4 LFS files: 100% 4/4 [00:02<00:00,  1.92it/s]
# ℹ Your model is pushed to the hub. You can view your model here:
# https://huggingface.co/sanjay-906/dqn-SpaceInvadersNoFrameskip-v4

# %% [markdown]
# Congrats 🥳 you've just trained and uploaded your first Deep Q-Learning agent using RL-Baselines-3 Zoo. The script above should have displayed a link to a model repository such as https://huggingface.co/ThomasSimonini/dqn-SpaceInvadersNoFrameskip-v4. When you go to this link, you can:
#
# - See a **video preview of your agent** at the right.
# - Click "Files and versions" to see all the files in the repository.
# - Click "Use in stable-baselines3" to get a code snippet that shows how to load the model.
# - A model card (`README.md` file) which gives a description of the model and the hyperparameters you used.
#
# Under the hood, the Hub uses git-based repositories (don't worry if you don't know what git is), which means you can update the model with new versions as you experiment and improve your agent.
#
# **Compare the results of your agents with your classmates** using the [leaderboard](https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard) 🏆

# %% [markdown]
# ## Load a powerful trained model 🔥
# - The Stable-Baselines3 team uploaded **more than 150 trained Deep Reinforcement Learning agents on the Hub**.
#
# You can find them here: 👉 https://huggingface.co/sb3
#
# Some examples:
# - Asteroids: https://huggingface.co/sb3/dqn-AsteroidsNoFrameskip-v4
# - Beam Rider: https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4
# - Breakout: https://huggingface.co/sb3/dqn-BreakoutNoFrameskip-v4
# - Road Runner: https://huggingface.co/sb3/dqn-RoadRunnerNoFrameskip-v4
#
# Let's load an agent playing Beam Rider: https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4

# %%
# %%html
# <video controls autoplay><source src="https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>

# %% [markdown]
# 1. We download the model using `rl_zoo3.load_from_hub`, and place it in a new folder that we can call `rl_trained`

# %%
# Download model and save it into the logs/ folder
# !python -m rl_zoo3.load_from_hub --algo dqn --env BeamRiderNoFrameskip-v4 -orga sb3 -f rl_trained/

# %% [markdown]
# 2. Let's evaluate if for 5000 timesteps

# %%
# !python -m rl_zoo3.enjoy --algo dqn --env BeamRiderNoFrameskip-v4 -n 5000  -f rl_trained/ --no-render

# %% [markdown]
# Why not trying to train your own **Deep Q-Learning Agent playing BeamRiderNoFrameskip-v4? 🏆.**
#
# If you want to try, check https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4#hyperparameters **in the model card, you have the hyperparameters of the trained agent.**

# %% [markdown]
# But finding hyperparameters can be a daunting task. Fortunately, we'll see in the next Unit, how we can **use Optuna for optimizing the Hyperparameters 🔥.**

# %% [markdown]
# ## Some additional challenges 🏆
# The best way to learn **is to try things by your own**!
#
# In the [Leaderboard](https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard) you will find your agents. Can you get to the top?
#
# Here's a list of environments you can try to train your agent with:
# - BeamRiderNoFrameskip-v4
# - BreakoutNoFrameskip-v4
# - EnduroNoFrameskip-v4
# - PongNoFrameskip-v4
#
# Also, **if you want to learn to implement Deep Q-Learning by yourself**, you definitely should look at CleanRL implementation: https://github.com/vwxyzjn/cleanrl/blob/master/cleanrl/dqn_atari.py
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit4/atari-envs.gif" alt="Environments"/>

# %% [markdown]
# ________________________________________________________________________
# Congrats on finishing this chapter!
#
# If you’re still feel confused with all these elements...it's totally normal! **This was the same for me and for all people who studied RL.**
#
# Take time to really **grasp the material before continuing and try the additional challenges**. It’s important to master these elements and having a solid foundations.
#
# In the next unit, **we’re going to learn about [Optuna](https://optuna.org/)**. One of the most critical task in Deep Reinforcement Learning is to find a good set of training hyperparameters. And Optuna is a library that helps you to automate the search.

# %% [markdown]
# ### This is a course built with you 👷🏿‍♀️
#
# Finally, we want to improve and update the course iteratively with your feedback. If you have some, please fill this form 👉 https://forms.gle/3HgA7bEHwAmmLfwh9
#
# We're constantly trying to improve our tutorials, so **if you find some issues in this notebook**, please [open an issue on the Github Repo](https://github.com/huggingface/deep-rl-class/issues).

# %% [markdown]
# See you on Bonus unit 2! 🔥

# %% [markdown]
# ### Keep Learning, Stay Awesome 🤗

# %%
# !python -m rl_zoo3.record_video \
  --env SpaceInvadersNoFrameskip-v4 \
  --algo dqn \
  --folder logs/ \
  --n-envs 1
# Out:
# 2025-01-25 18:50:42.854146: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-25 18:50:42.874220: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-25 18:50:42.880281: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-25 18:50:42.894638: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-25 18:50:43.972990: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Loading latest experiment, id=1
# Loading logs/dqn/SpaceInvadersNoFrameskip-v4_1/SpaceInvadersNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.10.1+unknown)
# [Powered by Stella]
# Stacking 4 frames
# Loading logs/dqn/SpaceInvadersNoFrameskip-v4_1/SpaceInvadersNoFrameskip-v4.zip
# Wrapping the env in a VecTransposeImage.
# Saving video to /content/logs/dqn/SpaceInvadersNoFrameskip-v4_1/videos/final-model-dqn-SpaceInvadersNoFrameskip-v4-step-0-to-step-1000.mp4
# Moviepy - Building video /content/logs/dqn/SpaceInvadersNoFrameskip-v4_1/videos/final-model-dqn-SpaceInvadersNoFrameskip-v4-step-0-to-step-1000.mp4.
# Moviepy - Writing video /content/logs/dqn/SpaceInvadersNoFrameskip-v4_1/videos/final-model-dqn-SpaceInvadersNoFrameskip-v4-step-0-to-step-1000.mp4
#
# Moviepy - Done !
# Moviepy - video ready /content/logs/dqn/SpaceInvadersNoFrameskip-v4_1/videos/final-model-dqn-SpaceInvadersNoFrameskip-v4-step-0-to-step-1000.mp4
